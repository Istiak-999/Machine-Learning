# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
df = pd.read_csv('online-courses-vs-traditional-courses3.csv')
df
# Out:
#     Online courses provide a better learning experience than traditional courses-  \
# 0                                                Agree
# 1                                             Disagree
# 2                                                Agree
# 3                                             Disagree
# 4                                             Disagree
# ..                                                 ...
# 929                                              Agree
# 930                                            Neutral
# 931                                  Strongly Disagree
# 932                                  Strongly Disagree
# 933                                           Disagree
#
#     Online courses require more of a students time than traditional courses-  \
# 0                                              Neutral
# 1                                             Disagree
# 2                                                Agree
# ...

# %%
df.keys()
# Out:
# Index(['Online courses provide a better learning experience than traditional courses-',
#        'Online courses require more of a students time than traditional courses-',
#        'An online course does not really need a teacher – it usually ends up being self directed learning-',
#        'The overall quality of online courses is better than that of traditional courses-',
#        'The amount of material that is presented to students in an online course is greater than in a traditional course-',
#        'Online courses are easier than traditional courses-',
#        'Students receive better quality teaching from online courses than they receive from traditional courses-',
#        'It is easier for students to cheat in online courses than in traditional courses-',
#        'Students learn more in online courses than they learn in traditional courses-',
#        'Students feel more disconnected from other students when taking online courses than when taking traditional courses-',
# ...

# %%
df.isna().sum()
# Out:
# Online courses provide a better learning experience than traditional courses-                                              0
# Online courses require more of a students time than traditional courses-                                                   1
# An online course does not really need a teacher – it usually ends up being self directed learning-                         0
# The overall quality of online courses is better than that of traditional courses-                                          0
# The amount of material that is presented to students in an online course is greater than in a traditional course-          0
# Online courses are easier than traditional courses-                                                                        0
# Students receive better quality teaching from online courses than they receive from traditional courses-                   0
# ...

# %%
df.dtypes
# Out:
# Online courses provide a better learning experience than traditional courses-                                              object
# Online courses require more of a students time than traditional courses-                                                   object
# An online course does not really need a teacher – it usually ends up being self directed learning-                         object
# The overall quality of online courses is better than that of traditional courses-                                          object
# The amount of material that is presented to students in an online course is greater than in a traditional course-          object
# Online courses are easier than traditional courses-                                                                        object
# Students receive better quality teaching from online courses than they receive from traditional courses-                   object
# ...

# %%
df.describe().T
# Out:
#                                                    count unique          top  \
# Online courses provide a better learning experi...   934      5     Disagree
# Online courses require more of a students time ...   933      5     Disagree
# An online course does not really need a teacher...   934      5      Neutral
# The overall quality of online courses is better...   934      5     Disagree
# The amount of material that is presented to stu...   934      5        Agree
# Online courses are easier than traditional cour...   934      5        Agree
# Students receive better quality teaching from o...   934      5     Disagree
# It is easier for students to cheat in online co...   934      5        Agree
# Students learn more in online courses than they...   934      5     Disagree
# Students feel more disconnected from other stud...   934      6        Agree
# Students feel more disconnected from their teac...   934      5        Agree
# ...

# %%
df['Online courses provide a better learning experience than traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online courses provide a better learning experience than traditional courses-'>

# %%
sn.histplot(x='Online courses provide a better learning experience than traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Online courses provide a better learning experience than traditional courses-', ylabel='Count'>

# %%
df['Online courses require more of a students time than traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online courses require more of a students time than traditional courses-'>

# %%
sn.histplot(x='Online courses require more of a students time than traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Online courses require more of a students time than traditional courses-', ylabel='Count'>

# %%
df['An online course does not really need a teacher – it usually ends up being self directed learning-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='An online course does not really need a teacher – it usually ends up being self directed learning-'>

# %%
sn.histplot(x='An online course does not really need a teacher – it usually ends up being self directed learning-',data=df)
# Out:
# <AxesSubplot:xlabel='An online course does not really need a teacher – it usually ends up being self directed learning-', ylabel='Count'>

# %%
df['The overall quality of online courses is better than that of traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='The overall quality of online courses is better than that of traditional courses-'>

# %%
sn.histplot(x='The overall quality of online courses is better than that of traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='The overall quality of online courses is better than that of traditional courses-', ylabel='Count'>

# %%
df['The amount of material that is presented to students in an online course is greater than in a traditional course-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='The amount of material that is presented to students in an online course is greater than in a traditional course-'>

# %%
sn.histplot(x='The amount of material that is presented to students in an online course is greater than in a traditional course-',data=df)
# Out:
# <AxesSubplot:xlabel='The amount of material that is presented to students in an online course is greater than in a traditional course-', ylabel='Count'>

# %%
df['Online courses are easier than traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online courses are easier than traditional courses-'>

# %%
sn.histplot(x='Online courses are easier than traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Online courses are easier than traditional courses-', ylabel='Count'>

# %%
df['Students receive better quality teaching from online courses than they receive from traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students receive better quality teaching from online courses than they receive from traditional courses-'>

# %%
sn.histplot(x='Students receive better quality teaching from online courses than they receive from traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students receive better quality teaching from online courses than they receive from traditional courses-', ylabel='Count'>

# %%
df['It is easier for students to cheat in online courses than in traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='It is easier for students to cheat in online courses than in traditional courses-'>

# %%
sn.histplot(x='It is easier for students to cheat in online courses than in traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='It is easier for students to cheat in online courses than in traditional courses-', ylabel='Count'>

# %%
df['Students learn more in online courses than they learn in traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students learn more in online courses than they learn in traditional courses-'>

# %%
sn.histplot(x='Students learn more in online courses than they learn in traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students learn more in online courses than they learn in traditional courses-', ylabel='Count'>

# %%
df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students feel more disconnected from other students when taking online courses than when taking traditional courses-'>

# %%
sn.histplot(x='Students feel more disconnected from other students when taking online courses than when taking traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students feel more disconnected from other students when taking online courses than when taking traditional courses-', ylabel='Count'>

# %%
df['Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-'>

# %%
sn.histplot(x='Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-', ylabel='Count'>

# %%
df['Students are more satisfied with online courses than they are with traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students are more satisfied with online courses than they are with traditional courses-'>

# %%
sn.histplot(x='Students are more satisfied with online courses than they are with traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students are more satisfied with online courses than they are with traditional courses-', ylabel='Count'>

# %%
df['Students must be more self motivated when taking online courses than when taking traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students must be more self motivated when taking online courses than when taking traditional courses-'>

# %%
sn.histplot(x='Students must be more self motivated when taking online courses than when taking traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students must be more self motivated when taking online courses than when taking traditional courses-', ylabel='Count'>

# %%
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'>

# %%
sn.histplot(x='Students must be more willing to teach themselves when taking online courses than when taking traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students must be more willing to teach themselves when taking online courses than when taking traditional courses-', ylabel='Count'>

# %%
df['Students who take online classes are more willing to spend the time on coursework than students in traditional classes-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students who take online classes are more willing to spend the time on coursework than students in traditional classes-'>

# %%
sn.histplot(x='Students who take online classes are more willing to spend the time on coursework than students in traditional classes-',data=df)
# Out:
# <AxesSubplot:xlabel='Students who take online classes are more willing to spend the time on coursework than students in traditional classes-', ylabel='Count'>

# %%
df['Students must spend more time reading course materials on their own when taking online courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students must spend more time reading course materials on their own when taking online courses-'>

# %%
sn.histplot(x='Students must spend more time reading course materials on their own when taking online courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students must spend more time reading course materials on their own when taking online courses-', ylabel='Count'>

# %%
df['Most students take online courses because they believe that online courses are easier than traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Most students take online courses because they believe that online courses are easier than traditional courses-'>

# %%
sn.histplot(x='Most students take online courses because they believe that online courses are easier than traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Most students take online courses because they believe that online courses are easier than traditional courses-', ylabel='Count'>

# %%
df['Students who take online courses must be more disciplined in their studying than students who take traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students who take online courses must be more disciplined in their studying than students who take traditional courses-'>

# %%
sn.histplot(x='Students who take online courses must be more disciplined in their studying than students who take traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Students who take online courses must be more disciplined in their studying than students who take traditional courses-', ylabel='Count'>

# %%
df['Professors are more available to students in online courses than in traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Professors are more available to students in online courses than in traditional courses-'>

# %%
sn.histplot(x='Professors are more available to students in online courses than in traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Professors are more available to students in online courses than in traditional courses-', ylabel='Count'>

# %%
df['Professors give feedback to students quicker in online courses than in traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Professors give feedback to students quicker in online courses than in traditional courses-'>

# %%
sn.histplot(x='Professors give feedback to students quicker in online courses than in traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Professors give feedback to students quicker in online courses than in traditional courses-', ylabel='Count'>

# %%
df['Professors give better quality instruction in online courses than in traditional courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Professors give better quality instruction in online courses than in traditional courses-'>

# %%
sn.histplot(x='Professors give better quality instruction in online courses than in traditional courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Professors give better quality instruction in online courses than in traditional courses-', ylabel='Count'>

# %%
df['Professors like teaching online courses-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Professors like teaching online courses-'>

# %%
sn.histplot(x='Professors like teaching online courses-',data=df)
# Out:
# <AxesSubplot:xlabel='Professors like teaching online courses-', ylabel='Count'>

# %%
df["It takes more of a professor's time to teach an online course than it does to teach a traditional course-"].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel="It takes more of a professor's time to teach an online course than it does to teach a traditional course-">

# %%
sn.histplot(x="It takes more of a professor's time to teach an online course than it does to teach a traditional course-",data=df)
# Out:
# <AxesSubplot:xlabel="It takes more of a professor's time to teach an online course than it does to teach a traditional course-", ylabel='Count'>

# %%
df['Online education is a good platform for theory classes-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online education is a good platform for theory classes-'>

# %%
sn.histplot(x='Online education is a good platform for theory classes-',data=df)
# Out:
# <AxesSubplot:xlabel='Online education is a good platform for theory classes-', ylabel='Count'>

# %%
df['Students easily access online/digital learning platforms'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Students easily access online/digital learning platforms'>

# %%
sn.histplot(x='Students easily access online/digital learning platforms',data=df)
# Out:
# <AxesSubplot:xlabel='Students easily access online/digital learning platforms', ylabel='Count'>

# %%
df['Online education requires lower tuition fees-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online education requires lower tuition fees-'>

# %%
sn.histplot(x='Online education requires lower tuition fees-',data=df)
# Out:
# <AxesSubplot:xlabel='Online education requires lower tuition fees-', ylabel='Count'>

# %%
df['Online education has obvious positive effect on the environment-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online education has obvious positive effect on the environment-'>

# %%
sn.histplot(x='Online education has obvious positive effect on the environment-',data=df)
# Out:
# <AxesSubplot:xlabel='Online education has obvious positive effect on the environment-', ylabel='Count'>

# %%
df['Online education does not provide enough lab sessions-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online education does not provide enough lab sessions-'>

# %%
sn.histplot(x='Online education does not provide enough lab sessions-',data=df)
# Out:
# <AxesSubplot:xlabel='Online education does not provide enough lab sessions-', ylabel='Count'>

# %%
df['Online education does not provide different kind of campus facilities'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Online education does not provide different kind of campus facilities'>

# %%
sn.histplot(x='Online education does not provide different kind of campus facilities',data=df)
# Out:
# <AxesSubplot:xlabel='Online education does not provide different kind of campus facilities', ylabel='Count'>

# %%
df['The Internet will create problems in online teaching-'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='The Internet will create problems in online teaching-'>

# %%
sn.histplot(x='The Internet will create problems in online teaching-',data=df)
# Out:
# <AxesSubplot:xlabel='The Internet will create problems in online teaching-', ylabel='Count'>

# %%
df['Target'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Target'>

# %%
sn.histplot(x='Target',data=df)
# Out:
# <AxesSubplot:xlabel='Target', ylabel='Count'>

# %%
df['Online courses provide a better learning experience than traditional courses-'].unique()
# Out:
# array(['Agree', 'Disagree', 'Strongly Disagree', 'Neutral',
#        'Strongly Agree'], dtype=object)

# %%
df['Online courses provide a better learning experience than traditional courses-'] = df['Online courses provide a better learning experience than traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online courses provide a better learning experience than traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 2, 1, 3, 5], dtype=int64)

# %%
df['Online courses require more of a students time than traditional courses-'].unique()
# Out:
# array(['Neutral', 'Disagree', 'Agree', 'Strongly Disagree',
#        'Strongly Agree', nan], dtype=object)

# %%
df['Online courses require more of a students time than traditional courses-'] = df['Online courses require more of a students time than traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online courses require more of a students time than traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([ 3.,  2.,  4.,  1.,  5., nan])

# %%
df['An online course does not really need a teacher – it usually ends up being self directed learning-'].unique()
# Out:
# array(['Disagree', 'Strongly Disagree', 'Neutral', 'Agree',
#        'Strongly Agree'], dtype=object)

# %%
df['An online course does not really need a teacher – it usually ends up being self directed learning-']=df['An online course does not really need a teacher – it usually ends up being self directed learning-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['An online course does not really need a teacher – it usually ends up being self directed learning-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
df['The overall quality of online courses is better than that of traditional courses-'].unique()
# Out:
# array(['Strongly Agree', 'Agree', 'Neutral', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['The overall quality of online courses is better than that of traditional courses-']=df['The overall quality of online courses is better than that of traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['The overall quality of online courses is better than that of traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
df['The amount of material that is presented to students in an online course is greater than in a traditional course-'].unique()
# Out:
# array(['Agree', 'Disagree', 'Neutral', 'Strongly Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['The amount of material that is presented to students in an online course is greater than in a traditional course-']=df['The amount of material that is presented to students in an online course is greater than in a traditional course-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['The amount of material that is presented to students in an online course is greater than in a traditional course-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 2, 3, 5, 1], dtype=int64)

# %%
df['Online courses are easier than traditional courses-'].unique()
# Out:
# array(['Strongly Agree', 'Agree', 'Neutral', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Online courses are easier than traditional courses-']=df['Online courses are easier than traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online courses are easier than traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
df['Students receive better quality teaching from online courses than they receive from traditional courses-'].unique()
# Out:
# array(['Strongly Agree', 'Disagree', 'Agree', 'Neutral',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students receive better quality teaching from online courses than they receive from traditional courses-']=df['Students receive better quality teaching from online courses than they receive from traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students receive better quality teaching from online courses than they receive from traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 2, 4, 3, 1], dtype=int64)

# %%
df['It is easier for students to cheat in online courses than in traditional courses-'].unique()
# Out:
# array(['Neutral', 'Strongly Agree', 'Agree', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['It is easier for students to cheat in online courses than in traditional courses-']=df['It is easier for students to cheat in online courses than in traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['It is easier for students to cheat in online courses than in traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([3, 5, 4, 2, 1], dtype=int64)

# %%
df['Students learn more in online courses than they learn in traditional courses-'].unique()
# Out:
# array(['Strongly Agree', 'Neutral', 'Agree', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students learn more in online courses than they learn in traditional courses-']=df['Students learn more in online courses than they learn in traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students learn more in online courses than they learn in traditional courses-'].unique()#Strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 3, 4, 2, 1], dtype=int64)

# %%
df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-'].unique()
# Out:
# array(['Agree', 'Neutral', 'Strongly Agree', 'Disagree',
#        'strongly Disagree', 'Strongly Disagree'], dtype=object)

# %%
df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-']=df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-'].replace(['strongly Disagree'], [1])
df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-'].unique()#set strongly Disagree=1,here s is small letter
# Out:
# array(['Agree', 'Neutral', 'Strongly Agree', 'Disagree', 1,
#        'Strongly Disagree'], dtype=object)

# %%
df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-']=df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students feel more disconnected from other students when taking online courses than when taking traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 3, 5, 2, 1], dtype=int64)

# %%
df['Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-'].unique()
# Out:
# array(['Strongly Agree', 'Agree', 'Neutral', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-']=df['Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students feel more disconnected from their teachers when taking online courses than when taking traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
df['Students are more satisfied with online courses than they are with traditional courses-'].unique()
# Out:
# array(['Agree', 'Disagree', 'Neutral', 'Strongly Disagree',
#        'Strongly Agree'], dtype=object)

# %%
df['Students are more satisfied with online courses than they are with traditional courses-']=df['Students are more satisfied with online courses than they are with traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students are more satisfied with online courses than they are with traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 2, 3, 1, 5], dtype=int64)

# %%
df['Students must be more self motivated when taking online courses than when taking traditional courses-'].unique()
# Out:
# array(['Agree', 'Neutral', 'Disagree', 'Strongly Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students must be more self motivated when taking online courses than when taking traditional courses-']=df['Students must be more self motivated when taking online courses than when taking traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students must be more self motivated when taking online courses than when taking traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].unique()
# Out:
# array(['Agree', 'Neutral', 'Strongly Agree', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-']=df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 3, 5, 2, 1], dtype=int64)

# %%
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].unique()
# Out:
# array([4, 3, 5, 2, 1], dtype=int64)

# %%
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-']=df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students must be more willing to teach themselves when taking online courses than when taking traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 3, 5, 2, 1], dtype=int64)

# %%
df['Students who take online classes are more willing to spend the time on coursework than students in traditional classes-'].unique()
# Out:
# array(['Agree', 'Neutral', 'Disagree', 'Strongly Disagree',
#        'Strongly Agree'], dtype=object)

# %%
df['Students who take online classes are more willing to spend the time on coursework than students in traditional classes-']=df['Students who take online classes are more willing to spend the time on coursework than students in traditional classes-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students who take online classes are more willing to spend the time on coursework than students in traditional classes-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 3, 2, 1, 5], dtype=int64)

# %%
df['Students must spend more time reading course materials on their own when taking online courses-'].unique()
# Out:
# array(['Agree', 'Strongly Agree', 'Neutral', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students must spend more time reading course materials on their own when taking online courses-']=df['Students must spend more time reading course materials on their own when taking online courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students must spend more time reading course materials on their own when taking online courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 5, 3, 2, 1], dtype=int64)

# %%
df['Most students take online courses because they believe that online courses are easier than traditional courses-'].unique()
# Out:
# array(['Agree', 'Disagree', 'Neutral', 'Strongly Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Most students take online courses because they believe that online courses are easier than traditional courses-']=df['Most students take online courses because they believe that online courses are easier than traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Most students take online courses because they believe that online courses are easier than traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 2, 3, 5, 1], dtype=int64)

# %%
df['Students who take online courses must be more disciplined in their studying than students who take traditional courses-'].unique()
# Out:
# array(['Disagree', 'Neutral', 'Agree', 'Strongly Disagree',
#        'Strongly Agree'], dtype=object)

# %%
df['Students who take online courses must be more disciplined in their studying than students who take traditional courses-']=df['Students who take online courses must be more disciplined in their studying than students who take traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students who take online courses must be more disciplined in their studying than students who take traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([2, 3, 4, 1, 5], dtype=int64)

# %%
df['Professors are more available to students in online courses than in traditional courses-'].unique()
# Out:
# array(['Neutral', 'Agree', 'Disagree', 'Strongly Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Professors are more available to students in online courses than in traditional courses-']=df['Professors are more available to students in online courses than in traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Professors are more available to students in online courses than in traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([3, 4, 2, 5, 1], dtype=int64)

# %%
df['Professors give feedback to students quicker in online courses than in traditional courses-'].unique()
# Out:
# array(['Neutral', 'Agree', 'Strongly Disagree', 'Disagree',
#        'Strongly Agree'], dtype=object)

# %%
df['Professors give feedback to students quicker in online courses than in traditional courses-']=df['Professors give feedback to students quicker in online courses than in traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Professors give feedback to students quicker in online courses than in traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([3, 4, 1, 2, 5], dtype=int64)

# %%
df['Professors give better quality instruction in online courses than in traditional courses-'].unique()
# Out:
# array(['Disagree', 'Neutral', 'Strongly Disagree', 'Agree',
#        'Strongly Agree'], dtype=object)

# %%
df['Professors give better quality instruction in online courses than in traditional courses-']=df['Professors give better quality instruction in online courses than in traditional courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Professors give better quality instruction in online courses than in traditional courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([2, 3, 1, 4, 5], dtype=int64)

# %%
df['Professors like teaching online courses-'].unique()
# Out:
# array(['Neutral', 'Disagree', 'Strongly Disagree', 'Agree',
#        'Strongly Agree'], dtype=object)

# %%
df['Professors like teaching online courses-']=df['Professors like teaching online courses-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Professors like teaching online courses-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([3, 2, 1, 4, 5], dtype=int64)

# %%
df["It takes more of a professor's time to teach an online course than it does to teach a traditional course-"].unique()
# Out:
# array(['Agree', 'Strongly Agree', 'Neutral', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df["It takes more of a professor's time to teach an online course than it does to teach a traditional course-"]=df["It takes more of a professor's time to teach an online course than it does to teach a traditional course-"].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df["It takes more of a professor's time to teach an online course than it does to teach a traditional course-"].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 5, 3, 2, 1], dtype=int64)

# %%
df['Online education is a good platform for theory classes-'].unique()
# Out:
# array(['Disagree', 'Agree', 'Neutral', 'Strongly Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Online education is a good platform for theory classes-']=df['Online education is a good platform for theory classes-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online education is a good platform for theory classes-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([2, 4, 3, 5, 1], dtype=int64)

# %%
df['Students easily access online/digital learning platforms'].unique()
# Out:
# array(['Strongly Agree', 'Agree', 'Disagree', 'Neutral',
#        'Strongly Disagree'], dtype=object)

# %%
df['Students easily access online/digital learning platforms']=df['Students easily access online/digital learning platforms'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Students easily access online/digital learning platforms'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 4, 2, 3, 1], dtype=int64)

# %%
df['Online education requires lower tuition fees-'].unique()
# Out:
# array(['Agree', 'Disagree', 'Strongly Agree', 'Neutral',
#        'Strongly Disagree'], dtype=object)

# %%
df['Online education requires lower tuition fees-']=df['Online education requires lower tuition fees-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online education requires lower tuition fees-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 2, 5, 3, 1], dtype=int64)

# %%
df['Online education has obvious positive effect on the environment-'].unique()
# Out:
# array(['Agree', 'Neutral', 'Disagree', 'Strongly Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Online education has obvious positive effect on the environment-']=df['Online education has obvious positive effect on the environment-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online education has obvious positive effect on the environment-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
df['Online education does not provide enough lab sessions-'].unique()
# Out:
# array(['Strongly Agree', 'Neutral', 'Agree', 'Disagree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Online education does not provide enough lab sessions-']=df['Online education does not provide enough lab sessions-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online education does not provide enough lab sessions-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 3, 4, 2, 1], dtype=int64)

# %%
df['Online education does not provide different kind of campus facilities'].unique()
# Out:
# array(['Strongly Agree', 'Neutral', 'Disagree', 'Agree',
#        'Strongly Disagree'], dtype=object)

# %%
df['Online education does not provide different kind of campus facilities']=df['Online education does not provide different kind of campus facilities'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['Online education does not provide different kind of campus facilities'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 3, 2, 4, 1], dtype=int64)

# %%
df['The Internet will create problems in online teaching-'].unique()
# Out:
# array(['Strongly Agree', 'Disagree', 'Agree', 'Strongly Disagree',
#        'Neutral'], dtype=object)

# %%
df['The Internet will create problems in online teaching-']=df['The Internet will create problems in online teaching-'].replace(['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree'], [1, 2, 3, 4, 5])
df['The Internet will create problems in online teaching-'].unique()#strongly Disagree=1,Disagree=2,Neutral=3,Agree=4,Strongly Agree=5
# Out:
# array([5, 2, 4, 1, 3], dtype=int64)

# %%
df['Target'].unique()
# Out:
# array(['Online', 'Traditional'], dtype=object)

# %%
df['Target']=df['Target'].replace(['Online', 'Traditional'], [0,1])
df['Target'].unique()#Online=0,Traditional=1
# Out:
# array([0, 1], dtype=int64)

# %%
df.head(10)
# Out:
#    Online courses provide a better learning experience than traditional courses-  \
# 0                                                  4
# 1                                                  2
# 2                                                  4
# 3                                                  2
# 4                                                  2
# 5                                                  1
# 6                                                  2
# 7                                                  2
# 8                                                  2
# 9                                                  3
#
#    Online courses require more of a students time than traditional courses-  \
# 0                                                3.0
# 1                                                2.0
# 2                                                4.0
# 3                                                2.0
# 4                                                4.0
# ...

# %%
df.dtypes
# Out:
# Online courses provide a better learning experience than traditional courses-                                                int64
# Online courses require more of a students time than traditional courses-                                                   float64
# An online course does not really need a teacher – it usually ends up being self directed learning-                           int64
# The overall quality of online courses is better than that of traditional courses-                                            int64
# The amount of material that is presented to students in an online course is greater than in a traditional course-            int64
# Online courses are easier than traditional courses-                                                                          int64
# Students receive better quality teaching from online courses than they receive from traditional courses-                     int64
# ...

# %%
df.describe().T
# Out:
#                                                     count      mean       std  \
# Online courses provide a better learning experi...  934.0  2.728051  1.300888
# Online courses require more of a students time ...  933.0  3.068596  1.276063
# An online course does not really need a teacher...  934.0  2.964668  1.240542
# The overall quality of online courses is better...  934.0  2.700214  1.253531
# The amount of material that is presented to stu...  934.0  3.261242  1.268911
# Online courses are easier than traditional cour...  934.0  3.262313  1.220025
# Students receive better quality teaching from o...  934.0  2.610278  1.218886
# It is easier for students to cheat in online co...  934.0  3.695931  1.193787
# Students learn more in online courses than they...  934.0  2.731263  1.231747
# Students feel more disconnected from other stud...  934.0  3.648822  1.152291
# Students feel more disconnected from their teac...  934.0  3.615632  1.171752
# ...

# %%
df.isna().sum()
# Out:
# Online courses provide a better learning experience than traditional courses-                                              0
# Online courses require more of a students time than traditional courses-                                                   1
# An online course does not really need a teacher – it usually ends up being self directed learning-                         0
# The overall quality of online courses is better than that of traditional courses-                                          0
# The amount of material that is presented to students in an online course is greater than in a traditional course-          0
# Online courses are easier than traditional courses-                                                                        0
# Students receive better quality teaching from online courses than they receive from traditional courses-                   0
# ...

# %%
#df = df.drop(['Online education has obvious positive effect on the environment-','Students are more satisfied with online courses than they are with traditional courses-','Students must be more self motivated when taking online courses than when taking traditional courses-',"It takes more of a professor's time to teach an online course than it does to teach a traditional course-",'Online education is a good platform for theory classes-'],axis='columns')

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (933, 31)

# %%
df.dtypes
# Out:
# Online courses provide a better learning experience than traditional courses-                                                int64
# Online courses require more of a students time than traditional courses-                                                   float64
# An online course does not really need a teacher – it usually ends up being self directed learning-                           int64
# The overall quality of online courses is better than that of traditional courses-                                            int64
# The amount of material that is presented to students in an online course is greater than in a traditional course-            int64
# Online courses are easier than traditional courses-                                                                          int64
# Students receive better quality teaching from online courses than they receive from traditional courses-                     int64
# ...

# %%
cols = ['Online courses require more of a students time than traditional courses-']
df[cols] = df[cols].applymap(np.int64)
# Out:
# C:\Users\Alpha11\AppData\Local\Temp\ipykernel_7412\2272935521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cols] = df[cols].applymap(np.int64)

# %%
df.dtypes
# Out:
# Online courses provide a better learning experience than traditional courses-                                              int64
# Online courses require more of a students time than traditional courses-                                                   int64
# An online course does not really need a teacher – it usually ends up being self directed learning-                         int64
# The overall quality of online courses is better than that of traditional courses-                                          int64
# The amount of material that is presented to students in an online course is greater than in a traditional course-          int64
# Online courses are easier than traditional courses-                                                                        int64
# Students receive better quality teaching from online courses than they receive from traditional courses-                   int64
# ...

# %%
X = df.drop('Target',axis='columns')
X[:10]
# Out:
#    Online courses provide a better learning experience than traditional courses-  \
# 0                                                  4
# 1                                                  2
# 2                                                  4
# 3                                                  2
# 4                                                  2
# 5                                                  1
# 6                                                  2
# 7                                                  2
# 8                                                  2
# 9                                                  3
#
#    Online courses require more of a students time than traditional courses-  \
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  2
# 4                                                  4
# ...

# %%
y = df['Target']
y[:10]
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# 5    1
# 6    1
# 7    1
# 8    1
# 9    0
# Name: Target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((746, 30), (187, 30), (746,), (187,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Decalare some array /list for storing outcome 
scores = []
model = []
mae = []
mse = []
rmse = []

# %%
# import classifier
from sklearn.svm import SVC

# initialize the classifier
linear_model.LinearRegression()
SVM.fit(X_train,y_train)

#use the resulting model to predict value on the test sey
y_pred = SVM.predict(X_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

model = np.append(model,"SVC")
sc1 = round(accuracy_score(y_test, y_pred),2)
scores = np.append(scores,sc1)
mae1 = metrics.mean_absolute_error(y_test, y_pred)
mae = np.append(mae,mae1)
mse1 = metrics.mean_squared_error(y_test, y_pred)
mse = np.append(mse,mse1)
rmse1 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
rmse = np.append(rmse,rmse1)
# Out:
# [[63 26]
#  [ 3 95]]
#
# Mean Absolute Error: 0.15508021390374332
# Mean Squared Error: 0.15508021390374332
# Root Mean Squared Error: 0.3938022522837361
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.71      0.81        89
#            1       0.79      0.97      0.87        98
#
#     accuracy                           0.84       187
#    macro avg       0.87      0.84      0.84       187
# weighted avg       0.87      0.84      0.84       187
#
# Accuracy: 0.8449197860962567

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix of Support Vector Classifier(SVC)')
# Out:
# Text(0.5, 1.0, 'Confusion matrix of Support Vector Classifier(SVC)')

# %%
# import classifier
from sklearn.ensemble import RandomForestClassifier

# initialize the Regressor
RFR = RandomForestClassifier()

#fit the regressor to the data
RFR.fit(X_train,y_train)

#use the resulting model to predict value on the test sey
y_pred = RFR.predict(X_test)
accuracy = RFR.score(X_test,y_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy)


model = np.append(model,"RandomForestClassifier")
sc2 = round(accuracy_score(y_test, y_pred),2)
scores = np.append(scores,sc2)
mae2 = metrics.mean_absolute_error(y_test, y_pred)
mae = np.append(mae,mae2)
mse2 = metrics.mean_squared_error(y_test, y_pred)
mse = np.append(mse,mse2)
rmse2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
rmse = np.append(rmse,rmse2)
# Out:
# [[81  8]
#  [ 2 96]]
#
# Mean Absolute Error: 0.053475935828877004
# Mean Squared Error: 0.053475935828877004
# Root Mean Squared Error: 0.23124864503144013
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94        89
#            1       0.92      0.98      0.95        98
#
#     accuracy                           0.95       187
#    macro avg       0.95      0.94      0.95       187
# weighted avg       0.95      0.95      0.95       187
#
# Accuracy: 0.946524064171123

# %%
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion matrix of Random Forest Classifier')
# Out:
# Text(0.5, 1.0, 'Confusion matrix of Random Forest Classifier')

# %%
# import classifier
from sklearn.tree import DecisionTreeClassifier

# initialize the Regressor
DTC = DecisionTreeClassifier()

#fit the regressor to the data
DTC.fit(X_train,y_train)

#use the resulting model to predict value on the test sey
y_pred = DTC.predict(X_test)
accuracy = DTC.score(X_test,y_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score


print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy)


model = np.append(model,"DecisionTreeClassifier")
sc2 = round(accuracy_score(y_test, y_pred),2)
scores = np.append(scores,sc2)
mae2 = metrics.mean_absolute_error(y_test, y_pred)
mae = np.append(mae,mae2)
mse2 = metrics.mean_squared_error(y_test, y_pred)
mse = np.append(mse,mse2)
rmse2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
rmse = np.append(rmse,rmse2)
# Out:
# [[83  6]
#  [ 2 96]]
#
# Mean Absolute Error: 0.0427807486631016
# Mean Squared Error: 0.0427807486631016
# Root Mean Squared Error: 0.20683507599800766
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95        89
#            1       0.94      0.98      0.96        98
#
#     accuracy                           0.96       187
#    macro avg       0.96      0.96      0.96       187
# weighted avg       0.96      0.96      0.96       187
#
# Accuracy: 0.9572192513368984

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion matrix of Decision Tree Classifier')
# Out:
# Text(0.5, 1.0, 'Confusion matrix of Decision Tree Classifier')

# %%
# import classifier
from sklearn.ensemble import GradientBoostingClassifier
# initialize the Regressor
gb_model = GradientBoostingClassifier()
#fit the regressor to the data

gb_model.fit(X_train,y_train)

#use the resulting model to predict value on the test sey
y_pred = gb_model.predict(X_test)
accuracy = gb_model.score(X_test,y_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score


print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy)

model = np.append(model,"GradientBoostingClassifier")
sc2 = round(accuracy_score(y_test, y_pred),2)
scores = np.append(scores,sc2)
mae2 = metrics.mean_absolute_error(y_test, y_pred)
mae = np.append(mae,mae2)
mse2 = metrics.mean_squared_error(y_test, y_pred)
mse = np.append(mse,mse2)
rmse2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
rmse = np.append(rmse,rmse2)
# Out:
# [[75 14]
#  [ 5 93]]
#
# Mean Absolute Error: 0.10160427807486631
# Mean Squared Error: 0.10160427807486631
# Root Mean Squared Error: 0.3187542596968177
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89        89
#            1       0.87      0.95      0.91        98
#
#     accuracy                           0.90       187
#    macro avg       0.90      0.90      0.90       187
# weighted avg       0.90      0.90      0.90       187
#
# Accuracy: 0.8983957219251337

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)


plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion matrix of Gradient Boosting Classifier')
# Out:
# Text(0.5, 1.0, 'Confusion matrix of Gradient Boosting Classifier')

# %%
# import classifier
from sklearn.ensemble import BaggingClassifier
# initialize the Regressor
bag_model = BaggingClassifier(
    n_estimators = 100,
    max_samples = 0.8,
    random_state=0
)
#fit the regressor to the data

bag_model.fit(X_train,y_train)
# Out:
# BaggingClassifier(max_samples=0.8, n_estimators=100, random_state=0)

# %%
#use the resulting model to predict value on the test sey
y_pred = bag_model.predict(X_test)
accuracy = bag_model.score(X_test,y_test)

#performance metrics
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score


print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy)

model = np.append(model,"BaggingClassifier")
sc2 = round(accuracy_score(y_test, y_pred),2)
scores = np.append(scores,sc2)
mae2 = metrics.mean_absolute_error(y_test, y_pred)
mae = np.append(mae,mae2)
mse2 = metrics.mean_squared_error(y_test, y_pred)
mse = np.append(mse,mse2)
rmse2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
rmse = np.append(rmse,rmse2)
# Out:
# [[83  6]
#  [ 4 94]]
#
# Mean Absolute Error: 0.053475935828877004
# Mean Squared Error: 0.053475935828877004
# Root Mean Squared Error: 0.23124864503144013
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        89
#            1       0.94      0.96      0.95        98
#
#     accuracy                           0.95       187
#    macro avg       0.95      0.95      0.95       187
# weighted avg       0.95      0.95      0.95       187
#
# Accuracy: 0.946524064171123

# %%
cm = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion matrix of Bagging Classifier')
# Out:
# Text(0.5, 1.0, 'Confusion matrix of Bagging Classifier')

# %%
#Visualize Models accuracy through bar and line

# %%
# bar plot


plt.rcParams["figure.figsize"] = [6.50, 4.50]
plt.rcParams["figure.autolayout"] = True

x = np.array(scores*100)
y = np.array(model)
plt.xlabel("Accuracy(%)")
plt.ylabel("Classification Models")
plt.title("Bar graph for Accuracy(%) per classification model")
plt.barh(y, x, color="green")
for index, value in enumerate(x):
    plt.text(value, index,
             str(value))

    
plt.show()

# %%
#line plot


plt.rcParams["figure.figsize"] = [5.50, 4.50]
plt.rcParams["figure.autolayout"] = True

x = np.array(scores*100)
y = np.array(model)
plt.xlabel("Accuracy(%)")
plt.ylabel("Classification Models")
plt.title("Line graph for Accuarcy(%) per classification model")
plt.plot(x, y, label ='accuracy')
for index, value in enumerate(x):
    plt.text(value, index,
             str(value))

plt.show()

# %%
#Visualize Models loss/error through bar and line

# %%
#line 


x = np.array(model)
y1 = np.array(mae)
y2 = np.array(mse)
y3 = np .array(rmse)

plt.plot(y1, x, label ='MAE')
plt.plot(y2,x, '-.', label ='MSE')
plt.plot(y3,x, '--.', label ='RMSE')

plt.xlabel("Error")
plt.ylabel("Classfication Model")
plt.legend()
plt.title('Line graph for error per classification model')
plt.show()

# %%
# bar

N = 5
ind = np.arange(N) #arange
width = 0.25
x = np.array(model)
y1 = np.array(mae)
y2 = np.array(mse)
y3 = np .array(rmse)

bar1 = plt.barh(ind, y1, width, color = 'r')
  
bar2 = plt.barh(ind+width, y2, width, color='g')
  
bar3 = plt.barh(ind+width*2, y3, width, color = 'b')
  
plt.xlabel("Error")
plt.ylabel('Classsification Models')
plt.title("Bar grap for error per classification models")
  
plt.yticks(ind+width,x)
plt.legend( (bar1, bar2, bar3), ('MAE', 'MSE', 'RMSE') )
plt.figure(figsize=(10,6))

plt.show()
